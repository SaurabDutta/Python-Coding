# %%
#Call Libraries
import numpy as np
import pandas as pd

# %%
#Load data from .csv file to dataframe
df=pd.read_csv("D:/Dummydata/Biometric_Data.csv")

# %%
df
# Out:
#           Date   Employee Code  Employee Name           Company  Department  \
# 0    9/20/2021              1.0          John  ABC Incorporation      Admin
# 1    9/21/2021              1.0          John  ABC Incorporation      Admin
# 2    9/22/2021              1.0          John  ABC Incorporation      Admin
# 3    9/23/2021              1.0          John  ABC Incorporation      Admin
# 4    9/24/2021              1.0          John  ABC Incorporation      Admin
# ..         ...              ...           ...                ...        ...
# 290        NaN              NaN           NaN                NaN        NaN
# 291        NaN              NaN           NaN                NaN        NaN
# 292        NaN              NaN           NaN                NaN        NaN
# 293        NaN              NaN           NaN                NaN        NaN
# 294        NaN              NaN           NaN                NaN        NaN
#
# ...

# %%
df.columns

# To see the columns available
# Out:
# Index(['Date', ' Employee Code ', 'Employee Name', 'Company ', 'Department',
#        'Category ', 'Degination', 'Grade', 'Team', 'Shift', ' In Time ',
#        'Out Time ', ' Duration '],
#       dtype='object')

# %%
for i in df['Employee Name']:
    print(i)
# Out:
# John
# John
# John
# John
# John
# Merry Math
# Merry Math
# Merry Math
# Merry Math
# Merry Math
# Stela Kevin
# Stela Kevin
# Stela Kevin
# Stela Kevin
# Stela Kevin
# Peter Molsberg
# Peter Molsberg
# Peter Molsberg
# Peter Molsberg
# Peter Molsberg
# Merry Charlton
# Merry Charlton
# Merry Charlton
# Merry Charlton
# Merry Charlton
# Kemlin Green
# Kemlin Green
# Kemlin Green
# Kemlin Green
# Kemlin Green
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
for i in df['Out Time '] :
    
    print(i)
    
 #Iteration through for loop to print a column data
# Out:
# nan
# nan
# nan
# 19:07
# 17:32
# nan
# nan
# 19:25
# 19:14
# 19:15
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 18:26
# nan
# nan
# 19:26
# 19:09
# 19:04
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
selected_rows = df[~df['Out Time ']. isna()]

# ~  is a not operation,it staands for negation. This will print all outtime of employees not having outtime as NaN

# %%
selected_rows
# Out:
#          Date   Employee Code    Employee Name           Company  Department  \
# 3   9/23/2021              1.0            John  ABC Incorporation      Admin
# 4   9/24/2021              1.0            John  ABC Incorporation      Admin
# 7   9/22/2021              2.0      Merry Math  ABC Incorporation   Contract
# 8   9/23/2021              2.0      Merry Math  ABC Incorporation   Contract
# 9   9/24/2021              2.0      Merry Math  ABC Incorporation   Contract
# 24  9/24/2021              5.0  Merry Charlton  ABC Incorporation       DBDR
# 27  9/22/2021              6.0    Kemlin Green  ABC Incorporation         HR
# 28  9/23/2021              6.0    Kemlin Green  ABC Incorporation         HR
# 29  9/24/2021              6.0    Kemlin Green  ABC Incorporation         HR
#
#    Category                Degination  Grade               Team Shift  \
# 3    Default  Senior Business Manager    NaN         Harry Buck    GS
# ...

# %%
selected_rows.to_excel("D:\Biometric_play.xlsx")

#Put the filtered output in the Excel file

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = selected_rows['Employee Name'].value_counts() 
# get x and y data 
points = data.index 
frequency = data.values 
# create bar chart 
ax.bar(points, frequency) 
# set title and labels 
ax.set_title('In Time Counts of Week') 
ax.set_xlabel('Employee Name')
# Out:
# Text(0.5, 0, 'Employee Name')

# %%
data
# Out:
# Kemlin Green      3
# Merry Math        3
# John              2
# Merry Charlton    1
# Name: Employee Name, dtype: int64

# %%
points
# Out:
# Index(['Kemlin Green', 'Merry Math', 'John', 'Merry Charlton'], dtype='object')
