# %%
#Call Libraries
import numpy as np
import pandas as pd

# %%
#Load data from .csv file to dataframe

df=pd.read_csv("D:/Dummydata/Biometric_Data.csv")

# %%
df
# Out:
#           Date   Employee Code  Employee Name           Company  Department  \
# 0    9/20/2021              1.0          John  ABC Incorporation      Admin
# 1    9/21/2021              1.0          John  ABC Incorporation      Admin
# 2    9/22/2021              1.0          John  ABC Incorporation      Admin
# 3    9/23/2021              1.0          John  ABC Incorporation      Admin
# 4    9/24/2021              1.0          John  ABC Incorporation      Admin
# ..         ...              ...           ...                ...        ...
# 290        NaN              NaN           NaN                NaN        NaN
# 291        NaN              NaN           NaN                NaN        NaN
# 292        NaN              NaN           NaN                NaN        NaN
# 293        NaN              NaN           NaN                NaN        NaN
# 294        NaN              NaN           NaN                NaN        NaN
#
#     Category                Degination  Grade        Team Shift  In Time   \
# 0     Default  Senior Business Manager    NaN  Harry Buck    GS       NaN
# 1     Default  Senior Business Manager    NaN  Harry Buck    GS       NaN
# 2     Default  Senior Business Manager    NaN  Harry Buck    GS       NaN
# 3     Default  Senior Business Manager    NaN  Harry Buck    GS     13:09
# 4     Default  Senior Business Manager    NaN  Harry Buck    GS     12:41
# ..        ...                      ...    ...         ...   ...       ...
# 290       NaN                      NaN    NaN         NaN   NaN       NaN
# 291       NaN                      NaN    NaN         NaN   NaN       NaN
# 292       NaN                      NaN    NaN         NaN   NaN       NaN
# 293       NaN                      NaN    NaN         NaN   NaN       NaN
# 294       NaN                      NaN    NaN         NaN   NaN       NaN
#
#     Out Time   Duration
# 0         NaN       0:00
# 1         NaN       0:00
# 2         NaN       0:00
# 3       19:07       5:58
# 4       17:32       4:50
# ..        ...        ...
# 290       NaN        NaN
# 291       NaN        NaN
# 292       NaN        NaN
# 293       NaN        NaN
# 294       NaN        NaN
#
# [295 rows x 13 columns]

# %%
df.columns

# To see the columns available
# Out:
# Index(['Date', ' Employee Code ', 'Employee Name', 'Company ', 'Department',
#        'Category ', 'Degination', 'Grade', 'Team', 'Shift', ' In Time ',
#        'Out Time ', ' Duration '],
#       dtype='object')

# %%
for i in df['Employee Name']:
    print(i)
# Out:
# John
# John
# John
# John
# John
# Merry Math
# Merry Math
# Merry Math
# Merry Math
# Merry Math
# Stela Kevin
# Stela Kevin
# Stela Kevin
# Stela Kevin
# Stela Kevin
# Peter Molsberg
# Peter Molsberg
# Peter Molsberg
# Peter Molsberg
# Peter Molsberg
# Merry Charlton
# Merry Charlton
# Merry Charlton
# Merry Charlton
# Merry Charlton
# Kemlin Green
# Kemlin Green
# Kemlin Green
# Kemlin Green
# Kemlin Green
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
for i in df['Out Time '] :
    
    print(i)
    
 #Iteration through for loop to print a column data
# Out:
# nan
# nan
# nan
# 19:07
# 17:32
# nan
# nan
# 19:25
# 19:14
# 19:15
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 18:26
# nan
# nan
# 19:26
# 19:09
# 19:04
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
selected_rows = dataframe[~dataframe['Out Time ']. isna()]

# ~  is a not operation,it staands for negation. This will print all outtime of employees not having outtime as NaN

# %%
selected_rows
# Out:
#          Date   Employee Code    Employee Name           Company  Department  \
# 3   9/23/2021              1.0            John  ABC Incorporation      Admin
# 4   9/24/2021              1.0            John  ABC Incorporation      Admin
# 7   9/22/2021              2.0      Merry Math  ABC Incorporation   Contract
# 8   9/23/2021              2.0      Merry Math  ABC Incorporation   Contract
# 9   9/24/2021              2.0      Merry Math  ABC Incorporation   Contract
# 24  9/24/2021              5.0  Merry Charlton  ABC Incorporation       DBDR
# 27  9/22/2021              6.0    Kemlin Green  ABC Incorporation         HR
# 28  9/23/2021              6.0    Kemlin Green  ABC Incorporation         HR
# 29  9/24/2021              6.0    Kemlin Green  ABC Incorporation         HR
#
#    Category                Degination  Grade               Team Shift  \
# 3    Default  Senior Business Manager    NaN         Harry Buck    GS
# 4    Default  Senior Business Manager    NaN         Harry Buck    GS
# 7    Default                  Manager    NaN                NaN    GS
# 8    Default                  Manager    NaN                NaN    GS
# 9    Default                  Manager    NaN                NaN    GS
# 24   Default                  Manager    NaN  Derek Stegelmeier    GS
# 27   Default               HR & Admin    NaN      Manidipa Aich    GS
# 28   Default               HR & Admin    NaN      Manidipa Aich    GS
# 29   Default               HR & Admin    NaN      Manidipa Aich    GS
#
#     In Time  Out Time   Duration
# 3      13:09     19:07       5:58
# 4      12:41     17:32       4:50
# 7       8:53     19:25      10:22
# 8      10:04     19:14       9:10
# 9       9:50     19:15       9:20
# 24      8:18     18:26       9:27
# 27      9:27     19:26       9:59
# 28      9:31     19:09       9:38
# 29      9:03     19:04      10:01

# %%
selected_rows
# Out:
#           Date  Employee Code             Employee Name  Company  Department  \
# 3    9/23/2021               1            Bhaskar Datta  Legal O2      Admin
# 4    9/24/2021               1            Bhaskar Datta  Legal O2      Admin
# 7    9/22/2021               2            Namrata Dutta  Legal O2   Contract
# 8    9/23/2021               2            Namrata Dutta  Legal O2   Contract
# 9    9/24/2021               2            Namrata Dutta  Legal O2   Contract
# 24   9/24/2021               5     Navonil Bhattacharya  Legal O2       DBDR
# 27   9/22/2021               6          Deborpita Nandi  Legal O2         HR
# 28   9/23/2021               6          Deborpita Nandi  Legal O2         HR
# 29   9/24/2021               6          Deborpita Nandi  Legal O2         HR
# 48   9/23/2021              10             Tanmoy Sukul  Legal O2         DB
# 53   9/23/2021              11        Dipankar Majumdar  Legal O2         DB
# 67   9/22/2021              14              Debojit Roy  Legal O2   Contract
# 73   9/23/2021              15           Kaninika Ghosh  Legal O2         DB
# 77   9/22/2021              16   Debadipta Bhattacharya  Legal O2         DB
# 78   9/23/2021              16   Debadipta Bhattacharya  Legal O2         DB
# 79   9/24/2021              16   Debadipta Bhattacharya  Legal O2         DB
# 88   9/23/2021              18             Malay Sarkar  Legal O2         DB
# 92   9/22/2021              19         Vikash Kumar Jha  Legal O2   Contract
# 106  9/21/2021              22             Saurab Dutta  Legal O2         DB
# 107  9/22/2021              22             Saurab Dutta  Legal O2         DB
# 108  9/23/2021              22             Saurab Dutta  Legal O2         DB
# 109  9/24/2021              22             Saurab Dutta  Legal O2         DB
# 123  9/23/2021              25              Anirban Sen  Legal O2         DB
# 162  9/22/2021              33             Poulami Bera  Legal O2         DR
# 182  9/22/2021              37            Manidipa Aich  Legal O2         HR
# 183  9/23/2021              37            Manidipa Aich  Legal O2         HR
# 184  9/24/2021              37            Manidipa Aich  Legal O2         HR
# 193  9/23/2021              39               Soumen Roy  Legal O2         DB
# 198  9/23/2021              40      Deblina Chakrabarty  Legal O2      Admin
# 199  9/24/2021              40      Deblina Chakrabarty  Legal O2      Admin
# 202  9/22/2021              41     Jaiwardhan Samdarshi  Legal O2   Contract
# 207  9/22/2021              42            Wizdan Parwez  Legal O2         DB
# 208  9/23/2021              42            Wizdan Parwez  Legal O2         DB
# 209  9/24/2021              42            Wizdan Parwez  Legal O2         DB
# 232  9/22/2021              47         Aniruddha Sarkar  Legal O2   Contract
# 237  9/22/2021              48  Sourav Mohan Chatterjee  Legal O2   Contract
# 255  9/20/2021           LG201                    LG201   Default    Default
# 256  9/21/2021           LG201                    LG201   Default    Default
# 257  9/22/2021           LG201                    LG201   Default    Default
# 258  9/23/2021           LG201                    LG201   Default    Default
# 259  9/24/2021           LG201                    LG201   Default    Default
# 261  9/21/2021         LG20118    Md Mohiuddin Siddique  Legal O2         IT
# 262  9/22/2021         LG20118    Md Mohiuddin Siddique  Legal O2         IT
# 263  9/23/2021         LG20118    Md Mohiuddin Siddique  Legal O2         IT
# 264  9/24/2021         LG20118    Md Mohiuddin Siddique  Legal O2         IT
# 265  9/20/2021           LGO20                    LGO20   Default    Default
# 267  9/22/2021           LGO20                    LGO20   Default    Default
# 268  9/23/2021           LGO20                    LGO20   Default    Default
# 277  9/22/2021        LGO20094               Ankita Roy  Legal O2   Contract
# 288  9/23/2021        LGO20124        Alok Kumar Mishra  Legal O2    Finance
# 289  9/24/2021        LGO20124        Alok Kumar Mishra  Legal O2    Finance
#
#     Category                      Degination    Grade                  Team  \
# 3     Default        Senior Business Manager      NaN            Harry Buck
# 4     Default        Senior Business Manager      NaN            Harry Buck
# 7     Default                        Manager      NaN                   NaN
# 8     Default                        Manager      NaN                   NaN
# 9     Default                        Manager      NaN                   NaN
# 24    Default                        Manager      NaN     Derek Stegelmeier
# 27    Default                     HR & Admin      NaN         Manidipa Aich
# 28    Default                     HR & Admin      NaN         Manidipa Aich
# 29    Default                     HR & Admin      NaN         Manidipa Aich
# 48    Default                        Manager      NaN     Derek Stegelmeier
# 53    Default                    Team Leader      NaN          Tanmoy Sukul
# 67    Default               Senior Associate      NaN         Namrata Dutta
# 73    Default                    Team Leader      NaN          Tanmoy Sukul
# 77    Default                    Team Leader      NaN          Tanmoy Sukul
# 78    Default                    Team Leader      NaN          Tanmoy Sukul
# 79    Default                    Team Leader      NaN          Tanmoy Sukul
# 88    Default               Senior Associate      NaN          Tanmoy Sukul
# 92    Default               Senior Associate      NaN         Namrata Dutta
# 106   Default                     IT Manager      NaN          Tanmoy Sukul
# 107   Default                     IT Manager      NaN          Tanmoy Sukul
# 108   Default                     IT Manager      NaN          Tanmoy Sukul
# 109   Default                     IT Manager      NaN          Tanmoy Sukul
# 123   Default                      Associate      NaN          Tanmoy Sukul
# 162   Default                      Associate      NaN  Navonil Bhattacharya
# 182   Default                     HR Manager      NaN            Harry Buck
# 183   Default                     HR Manager      NaN            Harry Buck
# 184   Default                     HR Manager      NaN            Harry Buck
# 193   Default            Senior Data Analyst      NaN          Tanmoy Sukul
# 198   Default      Personal Assistant to CEO      NaN            Harry Buck
# 199   Default      Personal Assistant to CEO      NaN            Harry Buck
# 202   Default               Senior Associate      NaN         Namrata Dutta
# 207   Default                      Associate      NaN          Tanmoy Sukul
# 208   Default                      Associate      NaN          Tanmoy Sukul
# 209   Default                      Associate      NaN          Tanmoy Sukul
# 232   Default               Senior Associate      NaN         Namrata Dutta
# 237   Default               Senior Associate      NaN         Namrata Dutta
# 255   Default                            NaN      NaN                   NaN
# 256   Default                            NaN      NaN                   NaN
# 257   Default                            NaN      NaN                   NaN
# 258   Default                            NaN      NaN                   NaN
# 259   Default                            NaN      NaN                   NaN
# 261   Default           System Administrator      NaN          Saurab Dutta
# 262   Default           System Administrator      NaN          Saurab Dutta
# 263   Default           System Administrator      NaN          Saurab Dutta
# 264   Default           System Administrator      NaN          Saurab Dutta
# 265   Default                            NaN      NaN                   NaN
# 267   Default                            NaN      NaN                   NaN
# 268   Default                            NaN      NaN                   NaN
# 277   Default               Senior Associate  Default         Namrata Dutta
# 288   Default  Manger of Finance & Reporting  Default            Harry Buck
# 289   Default  Manger of Finance & Reporting  Default            Harry Buck
#
#     Shift  In Time  Out Time   Duration
# 3      GS     13:09     19:07       5:58
# 4      GS     12:41     17:32       4:50
# 7      GS      8:53     19:25      10:22
# 8      GS     10:04     19:14       9:10
# 9      GS      9:50     19:15       9:20
# 24     GS      8:18     18:26       9:27
# 27     GS      9:27     19:26       9:59
# 28     GS      9:31     19:09       9:38
# 29     GS      9:03     19:04      10:01
# 48     GS      9:13     19:23      10:10
# 53     GS      8:04     15:18       6:19
# 67     GS      8:16     19:25      10:22
# 73     GS      8:47     18:24       9:21
# 77     GS      9:47     19:26       9:35
# 78     GS      9:22     19:13       9:46
# 79     GS      9:37     19:15       9:33
# 88     GS      7:02     17:42       8:43
# 92     GS      9:02     19:14      10:12
# 106    GS      9:14     19:30      10:16
# 107    GS      9:04     19:59      10:55
# 108    GS      8:54     20:02      10:58
# 109    GS      8:58     19:16      10:17
# 123    GS      7:37     17:57       8:53
# 162    GS      9:02     19:08      10:06
# 182    GS     11:16     19:47       8:31
# 183    GS      9:37     19:10       9:33
# 184    GS      9:10     19:17      10:07
# 193    GS      8:53     19:19      10:20
# 198    GS      9:51     19:13       9:22
# 199    GS     10:21     19:16       8:55
# 202    GS      8:57     19:09      10:10
# 207    GS      8:43     18:48       9:49
# 208    GS      8:14     19:07      10:08
# 209    GS      8:30     18:47       9:48
# 232    GS      9:02     19:10      10:08
# 237    GS      9:02     19:29      10:27
# 255    GS     13:59     18:33       4:34
# 256    GS     14:13     19:35       5:22
# 257    GS     11:14     20:00       8:46
# 258    GS      9:16     20:02      10:46
# 259    GS     11:36     19:17       7:41
# 261    GS     13:37     19:30       5:53
# 262    GS     11:08     19:55       8:47
# 263    GS      9:10     19:57      10:47
# 264    GS      9:26     19:12       9:46
# 265    GS      9:34     13:24       3:50
# 267    GS      9:10     11:18       2:08
# 268    GS      9:01     19:11      10:10
# 277    GS      9:02     19:29      10:27
# 288    GS      8:55     19:07      10:08
# 289    GS      9:24     18:37       9:13

# %%
selected_rows.to_excel("D:\Biometric_play.xlsx")
